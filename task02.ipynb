# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %% [markdown]
# Read the data set and have a look at the features.

# %%
test = pd.read_csv('./testA.csv', header = None, dtype='object')
print('test data shape:', test.shape)
# Out:
# test data shape: (200001, 46)

# %%
test.head(10)
# Out:
#        0         1     2             3            4      5         6   \
# 0      id  loanAmnt  term  interestRate  installment  grade  subGrade
# 1  800000   14000.0     3         10.99       458.28      B        B3
# 2  800001   20000.0     5         14.65       472.14      C        C5
# 3  800002   12000.0     3         19.99       445.91      D        D4
# 4  800003   17500.0     5         14.31       410.02      C        C4
# 5  800004   35000.0     3         17.09      1249.42      D        D1
# 6  800005   16000.0     3          5.32       481.84      A        A1
# 7  800006   25000.0     5         14.99       594.62      C        C4
# 8  800007    4500.0     3          7.35       139.67      A        A4
# 9  800008   12000.0     5         16.55       295.34      D        D2
#
#                 7                 8              9   ...    36    37    38  \
# 0  employmentTitle  employmentLength  homeOwnership  ...    n5    n6    n7
# ...

# %%
train = pd.read_csv('./train.csv', header = None, dtype='object')
print('train data shape:', train.shape)
# Out:
# train data shape: (800001, 47)

# %%
train.head(10)
# Out:
#    0         1     2             3            4      5         6   \
# 0  id  loanAmnt  term  interestRate  installment  grade  subGrade
# 1   0   35000.0     5         19.52       917.97      E        E2
# 2   1   18000.0     5         18.49        461.9      D        D2
# 3   2   12000.0     5         16.99       298.17      D        D3
# 4   3   11000.0     3          7.26       340.96      A        A4
# 5   4    3000.0     3         12.99       101.07      C        C2
# 6   5   11000.0     3          7.99       344.65      A        A5
# 7   6    2050.0     3          7.69        63.95      A        A4
# 8   7   11500.0     3         14.98       398.54      C        C3
# 9   8   12000.0     3         12.99       404.27      C        C2
#
#                 7                 8              9   ...    37    38    39  \
# 0  employmentTitle  employmentLength  homeOwnership  ...    n5    n6    n7
# 1            320.0           2 years              2  ...   9.0   8.0   4.0
# ...

# %%
sample_submit = pd.read_csv('./sample_submit.csv', header = None, dtype='object')
print('sample_submit data shape:',sample_submit.shape)
# Out:
# sample_submit data shape: (200001, 2)

# %%
sample_submit.head(10)
# Out:
#         0          1
# 0      id  isDefault
# 1  800000        0.5
# 2  800001        0.5
# 3  800002        0.5
# 4  800003        0.5
# 5  800004        0.5
# 6  800005        0.5
# 7  800006        0.5
# 8  800007        0.5
# 9  800008        0.5
